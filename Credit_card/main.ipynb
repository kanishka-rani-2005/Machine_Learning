# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# ## Using Logistic Regression
# ### Because it is a Classification Problem

# %%
import numpy as np;
import pandas as pd;
from sklearn.metrics import accuracy_score;
from sklearn.model_selection import train_test_split;
from sklearn.linear_model import LogisticRegression;
from sklearn.preprocessing import StandardScaler;

# %% [markdown]
# ## DATA COLLECTION AND PREPROCESSING

# %%
dataframe=pd.read_csv('./creditcard.csv')

# %%
dataframe.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataframe.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
dataframe.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
dataframe.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
dataframe.shape
# Out:
# (284807, 31)

# %% [markdown]
# #### This dataset is highly unbalanced
# ###### 0 has higher values as compared to 1 so we can't feed this data directly to train model

# %% [markdown]
# 0-> Normal Transaction
# 1->Fraudlent Transaction

# %%
dataframe['Class'].value_counts()
# print(dataframe['Class'].value_counts().sort_index())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ## Seperating Legit and Fraud Dataset

# %%
## Seperating the data for analysis
legit=dataframe[dataframe.Class==0]
fraud=dataframe[dataframe.Class==1]

# %%
print(legit.shape,fraud.shape)
# Out:
# (284315, 31) (492, 31)

# %%
## Statistical Measure of this data
## Amount is column in dataset
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
## Compare the values of Both Transaction Legit and Fraud
dataframe.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %%
## Build sample dataset from original containing similar distribution of normal transaction and fraudlent transaction
## The number of fraudlent transactions -> 492
## The number of normal transactions -> 284315

# %%
legit_sample=legit.sample(n=492)  ## take random sample from original legit of size 492

# %%
## Concate both
new_dataset=pd.concat([legit_sample,fraud],axis=0) ## row wise
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 148750   90169.0 -0.468145  0.017693  1.683322 -0.545361 -0.235745 -0.230008
# 109795   71541.0  0.856136 -1.421498 -0.569609 -0.721397 -0.616814 -0.033345
# 66707    52178.0  1.450506 -0.549833  0.097866 -1.051511 -0.549964 -0.076172
# 191577  129326.0  1.815944 -0.948659 -1.686614  0.458616  0.254221  0.585018
# 258515  158688.0  1.838152 -1.667607  0.142008 -1.243637 -1.416358  1.037052
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 148750  0.514394 -0.102782  1.582622  ...  0.173681  0.655592  0.072989
# 109795  0.001338 -0.180938 -1.240637  ... -0.220708 -0.841520 -0.387635
# 66707  -0.720493  0.062292 -0.858238  ... -0.129297 -0.549237 -0.011725
# 191577 -0.066073 -0.076796 -0.862689  ... -0.298638 -0.513114 -0.056120
# 258515 -1.768482  0.479598  0.871698  ... -0.034615  0.548386  0.374419
#
# ...

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95819.424797 -0.004288 -0.018025  0.038239 -0.027107 -0.021175
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.014972 -0.097821 -0.056614 -0.009336  ...  0.035950 -0.042399
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.008523 -0.010547  0.015922 -0.004949  0.061154  0.003826  0.000872
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       80.643598
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### UNIFORM DATA

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# Mean value of unbalanced dataset and balnaced dataset is almost similar
# So we can say it is a good dataset

# %% [markdown]
# ## Splitting Features and Targets

# %%
X=new_dataset.drop('Class',axis=1)
Y=new_dataset['Class']

# %%
X.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 148750   90169.0 -0.468145  0.017693  1.683322 -0.545361 -0.235745 -0.230008
# 109795   71541.0  0.856136 -1.421498 -0.569609 -0.721397 -0.616814 -0.033345
# 66707    52178.0  1.450506 -0.549833  0.097866 -1.051511 -0.549964 -0.076172
# 191577  129326.0  1.815944 -0.948659 -1.686614  0.458616  0.254221  0.585018
# 258515  158688.0  1.838152 -1.667607  0.142008 -1.243637 -1.416358  1.037052
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 148750  0.514394 -0.102782  1.582622  ...  0.071524  0.173681  0.655592
# 109795  0.001338 -0.180938 -1.240637  ...  0.229644 -0.220708 -0.841520
# 66707  -0.720493  0.062292 -0.858238  ...  0.070424 -0.129297 -0.549237
# 191577 -0.066073 -0.076796 -0.862689  ... -0.225993 -0.298638 -0.513114
# 258515 -1.768482  0.479598  0.871698  ... -0.527967 -0.034615  0.548386
#
# ...

# %%
Y.head()
# Out:
# 148750    0
# 109795    0
# 66707     0
# 191577    0
# 258515    0
# Name: Class, dtype: int64

# %% [markdown]
# ## Standardize the data

# %%
scaler=StandardScaler()

# %%
X=scaler.fit_transform(X)

# %%
X
# Out:
# array([[ 0.03923392,  0.34564647, -0.47137998, ..., -0.20462865,
#         -0.22837195,  0.01671046],
#        [-0.34830288,  0.58405249, -0.85140037, ..., -0.20917329,
#         -0.00290022,  0.98868917],
#        [-0.75113063,  0.69105506, -0.621236  , ..., -0.08492395,
#         -0.08760291, -0.44551734],
#        ...,
#        [ 1.68653581,  0.30820141, -0.17863349, ...,  0.29415299,
#          0.34625992, -0.11009581],
#        [ 1.69933026, -0.13064785, -0.32135371, ...,  0.78762347,
#         -0.64767957,  0.67155656],
#        [ 1.70727739,  0.78853419, -0.43420614, ..., -0.08315175,
#         -0.11885356, -0.27549122]])

# %% [markdown]
# ## Splitting the Data into Training and Testing Data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
print(Y.shape,Y_train.shape,Y_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)
# (984,) (787,) (197,)

# %% [markdown]
# ## Building Model

# %%
regression=LogisticRegression()

# %%
regression.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# ### Finding Accuarcy score for Trained data

# %%
X_train_pred=regression.predict(X_train)

prediction1=accuracy_score(X_train_pred,Y_train)

# %%
print('Prediction Score : ',prediction1)
# Out:
# Prediction Score :  0.951715374841169

# %%
X_test_pred=regression.predict(X_test)

prediction2=accuracy_score(X_test_pred,Y_test)

# %%
print('Prediction Score : ',prediction2)
# Out:
# Prediction Score :  0.9238578680203046

# %% [markdown]
# ## BUILDING PREDICTIVE SYSTEM

# %%
# input_data=(0,-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62)

input_data=(472,-3.0435406239976,-3.15730712090228,1.08846277997285,2.2886436183814,1.35980512966107,-1.06482252298131,0.325574266158614,-0.0677936531906277,-0.270952836226548,-0.838586564582682,-0.414575448285725,-0.503140859566824,0.676501544635863,-1.69202893305906,2.00063483909015,0.666779695901966,0.599717413841732,1.72532100745514,0.283344830149495,2.10233879259444,0.661695924845707,0.435477208966341,1.37596574254306,-0.293803152734021,0.279798031841214,-0.145361714815161,-0.252773122530705,0.0357642251788156,529)

arr=np.asarray(input_data)

# %%
arr_reshaped=arr.reshape(1,-1)

# %%
arr_reshaped
# Out:
# array([[ 4.72000000e+02, -3.04354062e+00, -3.15730712e+00,
#          1.08846278e+00,  2.28864362e+00,  1.35980513e+00,
#         -1.06482252e+00,  3.25574266e-01, -6.77936532e-02,
#         -2.70952836e-01, -8.38586565e-01, -4.14575448e-01,
#         -5.03140860e-01,  6.76501545e-01, -1.69202893e+00,
#          2.00063484e+00,  6.66779696e-01,  5.99717414e-01,
#          1.72532101e+00,  2.83344830e-01,  2.10233879e+00,
#          6.61695925e-01,  4.35477209e-01,  1.37596574e+00,
#         -2.93803153e-01,  2.79798032e-01, -1.45361715e-01,
#         -2.52773123e-01,  3.57642252e-02,  5.29000000e+02]])

# %% [markdown]
# ### Standardize the Input data

# %%
std_data=scaler.transform(arr_reshaped)

# %%
predict=regression.predict(std_data)

if(predict[0]==0):
    print("Legit Transaction")
else:
    print("Fraudlent Transaction")
# Out:
# Fraudlent Transaction
