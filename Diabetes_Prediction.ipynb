# %% [markdown]
# # DIABETES PREDICTION MODEL

# %% [markdown]
# ### IMPORTING ALL IMPORTANT LIBRRAIES

# %%
import numpy as np; # for numpy array
import pandas as pd;# for dataframe reading dataset file to dataframe 
from sklearn.preprocessing import StandardScaler # for standardization
from sklearn.model_selection import train_test_split #split data for  test and training model
from sklearn import svm # for import model support vector machine 
from sklearn.metrics import accuracy_score  #mantain accuracy score

# %% [markdown]
# ## Data collection and Analysis

# %% [markdown]
# # PIMA DIABETES DATASET

# %%
#loading the diabetes dataset to a pandas dataframe
#reading the data  and storing in dataframe
diabetes_dataset = pd.read_csv('diabetes.csv')

#displaying 5 rows of data 
# diabetes_dataset.head()

diabetes_dataset.__len__() # rows only 

diabetes_dataset.shape # for both rows and columns

# 9th column is label / outcome / target
# Out:
# (768, 9)

# %%
# getting the stastical measures of data

diabetes_dataset.describe()   # gives count mean std  quantiles max
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
diabetes_dataset['Outcome'].value_counts()
# 1 means person -> diabetic 
# 0 means person -> non diabetic
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.298000  109.980000  ...                  0.429734  31.190000
# 1           4.865672  141.257463  ...                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %% [markdown]
# # SEPERATING DATA AND LABELS

# %%
X=diabetes_dataset.drop(columns='Outcome',axis=1) # 1 means columns
Y=diabetes_dataset['Outcome']

print(X.head()) # to see the first 5 rows of the data
print(Y.head()) # to see the first 5 rows of the labels
# Out:
#    Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0            6      148             72  ...  33.6                     0.627   50
# 1            1       85             66  ...  26.6                     0.351   31
# 2            8      183             64  ...  23.3                     0.672   32
# 3            1       89             66  ...  28.1                     0.167   21
# 4            0      137             40  ...  43.1                     2.288   33
#
# [5 rows x 8 columns]
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# # DATA STANDARDIZATION
# Standardize the data using StandardScaler

# %%
# WHY ->  HEPLS MODEL TO MAKE BETTER PREDICTION AS VALUE IN ONLY BETWEEN 0 AND 1

scaler =StandardScaler() # taking one instances of standardscaler function
scaler.fit(X) # fitting the data to the scaler

standardize_data=scaler.transform(X)
standardize_data
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]], shape=(768, 8))

# %%
# #standardize_data=scaler.fit_transform(X)   # for both in one line fit and tranform
# instead of doing in separate lines

# %%
X=standardize_data  # assigning standardize data to X again

# %% [markdown]
# # FOR TRANING AND TESTING

# %%
X_train , X_test ,Y_train ,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# X_train ,X_test spliting The data X into these two 
# Y_train ,Y_test splititng The data Y into these two 
# 0.2 represent 20% of data is for test data 
# 80 % data for training data
# stratify Y to split data in same proportion
# so that not all cases of diabetic goes to  X _train  and non_diabetic goes to X_test
# random_state = 2  for replicating code

# %%
print(X.shape,X_train.shape,X_test.shape)
print(Y.shape,Y_train.shape,Y_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)
# (768,) (614,) (154,)

# %%
classifier=svm.SVC(kernel='linear') # support vector classifier

# %%
# training the support vector machine Classifier 
# parameters training data and label for training data 
classifier.fit(X_train,Y_train)

# trained model is stored in classifier
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # Evaluating The Model

# %%
# how many times our model is predicting correctly
# find accuracy score

# %%
X_train_prediction =classifier.predict(X_train)
# comparing model prediction with original prediction
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy score of the training data :',training_data_accuracy*100)
#  approx 79% model is predicting correctly
# Out:
# Accuracy score of the training data : 78.66449511400651

# %% [markdown]
# # Find accuracy score of test data

# %%
X_test_prediction=classifier.predict(X_test)
training_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy score of test data :',training_data_accuracy*100)
# there is no overtraining 
#  means accuracy score of training data is higher than accuracy score of test data
# Out:
# Accuracy score of test data : 77.27272727272727

# %% [markdown]
# # Making predictive System

# %%
input_data=(6,148,72,35,0,33.6,0.627,50)

# change input data to numpy array

arr=np.asarray(input_data)

#reshape the array

input_data_reshape=arr.reshape(1,-1)

# %% [markdown]
# # Standardize the input data

# %%
std_data=scaler.transform(input_data_reshape)

# print(std_data)

prediction=classifier.predict(std_data)

# print('Prediction : ',prediction)

if (prediction[0]==1):
    print('The Person is diabetic .')
else:
    print('The Person is not diabetic .')
# Out:
# The Person is diabetic .
# c:\Users\Kanishka\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
